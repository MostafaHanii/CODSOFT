# %% [markdown]
# <a href="https://colab.research.google.com/github/MostafaHanii/CODSOFT/blob/main/Copy_of_Speech_Emotion_Recognition_(SER).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'ravdess-emotional-speech-audio:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F107620%2F256618%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240805%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240805T154630Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,savee-database:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F251883%2F529602%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240805%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240805T154630Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,toronto-emotional-speech-set-tess:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F316368%2F639622%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240805%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240805T154630Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,cremad:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F325566%2F653195%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240805%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240805T154630Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,get-feature-xyscale1:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F5275698%2F8777644%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240805%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240805T154630Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,xy-scaler-120-mfcc:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F5283611%2F8788529%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240805%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240805T154630Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,final-all:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F5289457%2F8796609%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240805%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240805T154631Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading ravdess-emotional-speech-audio, 450102890 bytes compressed
# [==================================================] 450102890 bytes downloaded
# Downloaded and uncompressed: ravdess-emotional-speech-audio
# Downloading savee-database, 225403618 bytes compressed
# [==================================================] 225403618 bytes downloaded
# Downloaded and uncompressed: savee-database
# Downloading toronto-emotional-speech-set-tess, 448572034 bytes compressed
# [==================================================] 448572034 bytes downloaded
# Downloaded and uncompressed: toronto-emotional-speech-set-tess
# Downloading cremad, 473324524 bytes compressed
# [==================================================] 473324524 bytes downloaded
# Downloaded and uncompressed: cremad
# Downloading get-feature-xyscale1, 67075739 bytes compressed
# [==================================================] 67075739 bytes downloaded
# Downloaded and uncompressed: get-feature-xyscale1
# Downloading xy-scaler-120-mfcc, 79211714 bytes compressed
# [==================================================] 79211714 bytes downloaded
# Downloaded and uncompressed: xy-scaler-120-mfcc
# Downloading final-all, 304389719 bytes compressed
# [==================================================] 304389719 bytes downloaded
# Downloaded and uncompressed: final-all
# Data source import complete.

# %% [markdown]
# # <center>Speech Emotion Recognition (SER)</center>
#
# ##### What is Speech Emotion Recognition (SER)?
#
# * <span style="color:gray;">Speech Emotion Recognition (SER) is a technology and field of study that focuses on identifying and interpreting human emotions from speech signals. It involves analyzing various vocal attributes such as pitch, tone, intensity, rhythm, and speech rate to detect and classify emotions such as happiness, sadness, anger, fear, surprise, and neutrality.</span>
#
# ##### Why we need it?
#
# 1. <span style="color:gray;">**Improved Human-Computer Interaction:** SER enhances the way humans interact with machines by making these interactions more natural and intuitive. Emotionally aware systems can respond more appropriately to user emotions, improving user experience.</span>
#
# 2. <span style="color:gray;">**Customer Service:** In customer service, SER can help detect customer emotions during calls, enabling agents or automated systems to respond empathetically and effectively, improving customer satisfaction and loyalty.</span>
#
# 3. <span style="color:gray;">**Mental Health Assessment:** SER can aid in monitoring and diagnosing mental health conditions by identifying emotional patterns and anomalies in speech, providing valuable insights for healthcare providers.</span>
#
# 4. <span style="color:gray;">**Enhanced Communication:** For individuals with communication disorders, SER can assist in interpreting and conveying their emotional states, facilitating better understanding and interaction with others.</span>
#
# 5. <span style="color:gray;">**Personal Assistants:** Virtual assistants like Siri, Alexa, and Google Assistant can become more effective by recognizing user emotions, allowing them to provide more personalized and context-aware responses.</span>
#
# 6. <span style="color:gray;">**Security and Surveillance:** In security and surveillance, SER can help in identifying distress or potential threats by analyzing the emotional content in speech, enhancing safety and security measures.</span>
#
# 7. <span style="color:gray;">**Education:** SER can be used in educational tools to gauge student engagement and emotional states, allowing educators to adapt their teaching methods for better learning outcomes.</span>
#
# 8. <span style="color:gray;">**Entertainment:** In gaming and other entertainment applications, SER can create more immersive and responsive experiences by adjusting content based on the user’s emotional responses.</span>
#
# ##### Datasets used in this project
#
# * <span style="color:gray;">**Crowd-sourced Emotional Mutimodal Actors Dataset (Crema-D)**</span>
# * <span style="color:gray;">**Ryerson Audio-Visual Database of Emotional Speech and Song (Ravdess)**</span>
# * <span style="color:gray;">**Surrey Audio-Visual Expressed Emotion (Savee)**</span>
# * <span style="color:gray;">**Toronto emotional speech set (Tess)**</span>

# %% [markdown]
# ##  Impotring Libraries

# %%
import pandas as pd
import numpy as np
import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.callbacks import ModelCheckpoint

import joblib

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ##  Impotring Datasets

# %% [markdown]
# ## <center> Crema-D Dataset</center>

# %%
def import_cremaD(path):

    directory = '/path/to/directory/'
    folders = [f for f in os.listdir(path) ]
    emo = []
    fullName = []
    for folder in folders:
        files=os.listdir(path+folder)
        for file in files:
            fullName.append(path+folder+"/"+file)
            step = file.split('.')[0]
            emo.append(cremaD_convert(step))

    data={"path":fullName,"emotion":emo}
    df=pd.DataFrame(data)
    return df

# %% [markdown]
# ## <center> RAVDESS Dataset </center>
#
# Here is the filename identifiers as per the official RAVDESS website:
#
# * <span style="color:gray;"> Modality (01 = full-AV, 02 = video-only, 03 = audio-only).</span>
# * <span style="color:gray;">Vocal channel (01 = speech, 02 = song).</span>
# * <span style="color:gray;">Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).</span>
# * <span style="color:gray;">Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.</span>
# * <span style="color:gray;">Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").</span>
# * <span style="color:gray;">Repetition (01 = 1st repetition, 02 = 2nd repetition).</span>
# * <span style="color:gray;">Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).</span>
#
# So, here's an example of an audio filename. 02-01-06-01-02-01-12.mp4 This means the meta data for the audio file is:
#
# * <span style="color:gray;">Video-only (02)</span>
# * <span style="color:gray;">Speech (01)</span>
# * <span style="color:gray;">Fearful (06)</span>
# * <span style="color:gray;">Normal intensity (01)</span>
# * <span style="color:gray;">Statement "dogs" (02)</span>
# * <span style="color:gray;">1st Repetition (01)</span>
# * <span style="color:gray;">12th Actor (12) - Female (as the actor ID number is even)</span>

# %%
def import_ravdess(path):

    directory = '/path/to/directory'
    exclude_folder = 'audio_speech_actors_01-24'
    folders = [f for f in os.listdir(path+exclude_folder) ]
    emo = []
    fullName = []
    for folder in folders:
        files=os.listdir(path+folder)
        for file in files:
            fullName.append(path+folder+"/"+file)
            step = file.split('.')[0]
            emotion=int(step.split('-')[2])
            if emotion == 2:
                emotion = 1
            emo.append(emotion)
    data={"path":fullName,"emotion":emo}
    df=pd.DataFrame(data)
    return df

# %% [markdown]
# ## <center>SAVEE Dataset</center>

# %%
def import_savee(path):

    directory = '/path/to/directory/'
    exclude_folder = 'audiodata/AudioData'
    folders = [f for f in os.listdir(path+exclude_folder) ]
    emo = []
    fullName = []
    for folder in folders:
        if path+'AudioData/'+folder == '/kaggle/input/savee-database/AudioData/Info.txt':
            continue
        files=os.listdir(path+'AudioData/'+folder)
        for file in files:
            fullName.append(path+'AudioData/'+folder+"/"+file)
            step = file.split('.')[0]
            emo.append(savee_convert(step))


    data={"path":fullName,"emotion":emo}
    df=pd.DataFrame(data)
    return df

# %% [markdown]
# ## <center> TESS Dataset</center>

# %%
def import_tess(path):

    directory = '/path/to/directory/'
    folders = [f for f in os.listdir(path) ]
    emo = []
    fullName = []
    for folder in folders:
        files=os.listdir(path+folder)
        for file in files:
            fullName.append(path+folder+"/"+file)
            step = file.split('.')[0]
            emo.append(tess_convert(step))

    data={"path":fullName,"emotion":emo}
    df=pd.DataFrame(data)
    return df

# %% [markdown]
# ##  Data preparation
# 1. <span style="color:gray;">Convert a given emotion name to numeric value based on predefined mappings in RAVDESS</span>
#
# 2. <span style="color:gray;">Define the paths to the datasets</span>
#
# 3. <span style="color:gray;">Import each dataset into a dataframe by their paths</span>
#
# 4. <span style="color:gray;">Concatenate the dataframes into a single dataframe</span>
#
# 5. <span style="color:gray;">Shuffle the combined dataframe</span>
#
# 6. <span style="color:gray;">Create a copy of the combined dataframe with emotion names for data visualization</span>

# %%
def cremaD_convert(name):
    ch = name.split('_')[2]
    if ch == 'ANG':
        return 5
    elif ch == 'DIS':
        return 7
    elif ch == 'FEA':
        return 6
    elif ch == 'HAP':
        return 3
    elif ch == 'NEU':
        return 1
    elif ch == 'SAD':
        return 4

# %%
def savee_convert(name):
    ch = name[0]


    if ch == 's':
        ch+=name[1]


    if ch == 'a':
        return 5
    elif ch == 'd':
        return 7
    elif ch == 'f':
        return 6
    elif ch == 'h':
        return 3
    elif ch == 'n':
        return 1
    elif ch == 'sa':
        return 4
    elif ch == 'su':
        return 8

# %%
def tess_convert(name):
    ch = name.split('_')[2]
    if ch == 'angry':
        return 5
    elif ch == 'disgust':
        return 7
    elif ch == 'fear':
        return 6
    elif ch == 'happy':
        return 3
    elif ch == 'neutral':
        return 1
    elif ch == 'sad':
        return 4
    elif ch == 'ps':
        return 8

# %%
# Paths of the datasets
path="/kaggle/input/ravdess-emotional-speech-audio/"
path2='/kaggle/input/savee-database/'
path3='/kaggle/input/cremad/'
path4='/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/'

# Import each dataset into a dataframe
df=import_ravdess(path)
df2 =import_savee(path2)
df3 = import_cremaD(path3)
df4 = import_tess(path4)

# Concatenate all dataframes into a single dataframe
df=pd.concat([df,df2,df3,df4])

# Shuffle the combined dataframe
df = df.sample(frac=1).reset_index(drop=True)

# %%
# Create a copy of the combined dataframe with emotion names for data visualization
df_vis = df
df_vis.emotion = df.emotion.replace({1:'Neutral', 3:'Happy', 4:'Sad', 5:'Angry', 6:'Fear', 7:'Disgust', 8:'Surprise'})

# %%
df_vis.head(20)
# Out:
#                                                  path   emotion
# 0   /kaggle/input/cremad/AudioWAV/1012_ITH_NEU_XX.wav   Neutral
# 1   /kaggle/input/toronto-emotional-speech-set-tes...   Neutral
# 2   /kaggle/input/cremad/AudioWAV/1005_IEO_ANG_HI.wav     Angry
# 3   /kaggle/input/toronto-emotional-speech-set-tes...     Angry
# 4   /kaggle/input/cremad/AudioWAV/1058_IEO_DIS_HI.wav   Disgust
# 5   /kaggle/input/cremad/AudioWAV/1046_WSI_NEU_XX.wav   Neutral
# 6   /kaggle/input/ravdess-emotional-speech-audio/A...       Sad
# 7   /kaggle/input/savee-database/AudioData/JE/f10.wav      Fear
# 8   /kaggle/input/toronto-emotional-speech-set-tes...     Angry
# 9   /kaggle/input/toronto-emotional-speech-set-tes...     Happy
# 10  /kaggle/input/cremad/AudioWAV/1004_MTI_HAP_XX.wav     Happy
# 11  /kaggle/input/cremad/AudioWAV/1074_IOM_FEA_XX.wav      Fear
# 12  /kaggle/input/cremad/AudioWAV/1020_TAI_FEA_XX.wav      Fear
# 13  /kaggle/input/cremad/AudioWAV/1058_IWW_FEA_XX.wav      Fear
# 14  /kaggle/input/cremad/AudioWAV/1013_IEO_FEA_MD.wav      Fear
# 15  /kaggle/input/cremad/AudioWAV/1041_ITH_FEA_XX.wav      Fear
# 16  /kaggle/input/cremad/AudioWAV/1020_WSI_ANG_XX.wav     Angry
# 17  /kaggle/input/toronto-emotional-speech-set-tes...  Surprise
# 18  /kaggle/input/toronto-emotional-speech-set-tes...   Neutral
# 19  /kaggle/input/toronto-emotional-speech-set-tes...   Neutral

# %% [markdown]
# ## Data visualization and Exploration

# %% [markdown]
# <span style="color:gray;font-size:18px;">Count of each emotion in our combined dataframe</span>

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.title('Count of Emotions', size=14, fontweight='bold')

palette = sns.color_palette("Set2")
count = sns.countplot(x='emotion', data=df_vis, palette=palette)

plt.ylabel('Count', size=12, fontweight='bold')
plt.xlabel('Emotions', size=12, fontweight='bold')

plt.xticks(rotation=45, size=12)

sns.despine(top=True, right=True)

plt.grid(axis='y', linestyle='--', alpha=0.7)

for p in count.patches:
    count.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline',
                fontsize=10, color='black')


plt.show()
# Out:
# <ipython-input-30-6481d6acad12>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   count = sns.countplot(x='emotion', data=df_vis, palette=palette)
# <ipython-input-30-6481d6acad12>:6: UserWarning: The palette list has more values (8) than needed (7), which may not be intended.
#   count = sns.countplot(x='emotion', data=df_vis, palette=palette)

# %% [markdown]
# <span style="color:gray;font-size:18px;">Waveplots and Spectograms for audio signals</span>
# * <span style="color:gray;font-size:14px;">Waveplots let us know the loudness of the audio at a given time. </span>
# * <span style="color:gray;font-size:14px;">A spectrogram is a visual representation of the spectrum of frequencies of sound or other signals as they vary with time. It’s a representation of frequencies changing with respect to time for given audio/music signals. </span>

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
# emotion='fear'
# path = np.array(df_vis.path[df_vis.emotion==emotion])[1]
# data, sampling_rate = librosa.load(path)
# create_waveplot(data, sampling_rate, emotion)
# create_spectrogram(data, sampling_rate, emotion)
# Audio(path)

# %%
# emotion='angry'
# path = np.array(df_vis.path[df_vis.emotion==emotion])[1]
# data, sampling_rate = librosa.load(path)
# create_waveplot(data, sampling_rate, emotion)
# create_spectrogram(data, sampling_rate, emotion)
# Audio(path)

# %%
# emotion='sad'
# path = np.array(df_vis.path[df_vis.emotion==emotion])[1]
# data, sampling_rate = librosa.load(path)
# create_waveplot(data, sampling_rate, emotion)
# create_spectrogram(data, sampling_rate, emotion)
# Audio(path)

# %%
# emotion='happy'
# path = np.array(df_vis.path[df_vis.emotion==emotion])[1]
# data, sampling_rate = librosa.load(path)
# create_waveplot(data, sampling_rate, emotion)
# create_spectrogram(data, sampling_rate, emotion)
# Audio(path)

# %% [markdown]
# ## Data Augmentation
#
# * <span style="color:gray;">Data augmentation is the process by which we create new synthetic data samples by adding small perturbations on our initial training set.</span>
# * <span style="color:gray;">To generate syntactic data for audio, we can apply noise injection, shifting time, changing pitch and speed.</span>
# * <span style="color:gray;">The objective is to make our model invariant to those perturbations and enhace its ability to generalize.</span>
#
# <span style="color:gray;">Let's check which augmentation techniques works better for our dataset.</span>

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, r):
    r = librosa.get_duration(y=data,sr=r)
    r = 7/r
    return librosa.effects.time_stretch(data, rate = r)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, ns = 13):
    return librosa.effects.pitch_shift(data, sr = sampling_rate, n_steps = ns)

# taking any example and checking for techniques.
path = np.array(df.path)[1]
data, sample_rate = librosa.load(path)

# %% [markdown]
# 1. Simple Data

# %%
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=data, sr=sample_rate)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 2. Noise

# %%
x = noise(data)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 3. Stretching

# %%
x = stretch(data, sample_rate)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 4. Shifting

# %%
x = shift(data)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 5. Pitch

# %%
x = pitch(data, sample_rate)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <span style="color:gray;font-size:18px;">From the above data augmentation techniques, we work with noise and some pitching</span>

# %% [markdown]
# ## Feature Extraction
# * <span style="color:gray;"> Extraction of features is a very important part in analyzing and finding relations between different things. As we already know that the data provided of audio cannot be understood by the models directly so we need to convert them into an understandable format for which feature extraction is used.</span>
#
# <span style="color:gray;"> We are extracting 3 features: </span>
# * <span style="color:gray;"> Zero Crossing Rate (ZCR): The rate of sign-changes of the signal during the duration of a particular frame.</span>
# * <span style="color:gray;"> Root Mean Square (RMS).</span>
# * <span style="color:gray;"> Mel Frequency Cepstral Coefficients (MFCC) form a cepstral representation where the frequency bands are not linear but distributed according to the mel-scale.</span>

# %%
def extract_feature(data, sample_rate):
    frame_length=1024
    hop_length=512
    results = np.array([])

    #Zero Crossing Rate (Horizontal Crossing)
    zcr = librosa.feature.zero_crossing_rate(y = data, frame_length=frame_length, hop_length=hop_length)
    zcr = np.squeeze(zcr)
    zcr = librosa.util.fix_length(zcr, size=108, axis=0)

    #RMS
    rms = np.squeeze(librosa.feature.rms(y=data,frame_length=frame_length,hop_length=hop_length))
    rms = librosa.util.fix_length(rms, size=108, axis=0)

    #MFCC
    mfcc = librosa.feature.mfcc(y=data, sr=22050,n_fft=frame_length, hop_length=hop_length, n_mfcc=40)
    mfcc = np.ravel(mfcc.T)
    mfcc = librosa.util.fix_length(mfcc, size=4320, axis=0)

    results = np.hstack((results,zcr,rms,mfcc))
    return results

def get_feature(path2):
    data, sample_rate = librosa.load(path2, duration = 2.5, offset = 0.6)

#Simple data
    res1 = extract_feature(data, sample_rate)

#data with noise
    noise_data = noise(data)
    res2 = extract_feature(noise_data,sample_rate)

#data with noise
    pitch_data = pitch(data, sample_rate, ns = 13)
    res3 = extract_feature(pitch_data, sample_rate)

#pitched data with noise
    pitched_noisy_data = pitch(data, sample_rate, ns = 13)
    pitched_noisy_data = noise(pitched_noisy_data)
    res4 = extract_feature(pitched_noisy_data, sample_rate)

    return res1,res2,res3,res4

# %% [markdown]
# <span style="color:gray;font-size:18px;">Get the 3 features of the data and save them into a dataframe</span>

# %%
X_r1,X_r2,X_r3,X_r4,y_1,y_2,y_3,y_4 = [],[],[],[],[],[],[],[]
for i in range(len(df)):
    f1,f2,f3,f4=get_feature(df.iloc[i].path)
    X_r1.append(f1)
    X_r2.append(f2)
    X_r3.append(f3)
    X_r4.append(f4)
    y_1.append(df.iloc[i].emotion)
    y_2.append(df.iloc[i].emotion)
    y_3.append(df.iloc[i].emotion)
    y_4.append(df.iloc[i].emotion)

# %%
df1=np.array(X_r1)
df1=np.vstack((df1,X_r2))
df1=np.vstack((df1,X_r3))
df1=np.vstack((df1,X_r4))
df1=pd.DataFrame(df1)
y = y_1 + y_2 + y_3 + y_4
y = np.array(y)
X = df1
df1.shape
# Out:
# (48648, 4536)

# %%
Y_r = list(y)
X_r1_path = os.path.join('/kaggle/working', 'X_r1.pkl')
X_r2_path = os.path.join('/kaggle/working', 'X_r2.pkl')
X_r3_path = os.path.join('/kaggle/working', 'X_r3.pkl')
X_r4_path = os.path.join('/kaggle/working', 'X_r4.pkl')
Y_r_path = os.path.join('/kaggle/working', 'Y_r.pkl')

import pickle

with open(X_r1_path, 'wb') as f:
    pickle.dump(X_r1, f)

with open(X_r2_path, 'wb') as f:
    pickle.dump(X_r2, f)

with open(X_r3_path, 'wb') as f:
    pickle.dump(X_r3, f)

with open(X_r4_path, 'wb') as f:
    pickle.dump(X_r4, f)

with open(Y_r_path, 'wb') as f:
    pickle.dump(Y_r, f)

print(f"X_r1 and X_r2 saved to: {X_r1_path}, {X_r2_path}")
# Out:
# X_r1 and X_r2 saved to: /kaggle/working/X_r1.pkl, /kaggle/working/X_r2.pkl

# %% [markdown]
# <span style="color:gray;font-size:18px;"> We already got features and saved them, so we just want to load them</span>

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# from google.colab import files
# import zipfile
# import os

# # Step 1: Upload the zip file
# filename= "/content/drive/MyDrive/archive (5).zip"

# # Step 2: Decompress the zip file
# with zipfile.ZipFile(filename, 'r') as zip_ref:
#         zip_ref.extractall('/content')

#     # Verify the files are extracted
# extracted_files = os.listdir('/content')
# print('Extracted files:', extracted_files)

# %%
# import pickle
# X_r1_path=r'/content/X_r1 (1).pkl'
# X_r2_path=r'/content/X_r2 (1).pkl'
# X_r3_path=r'/content/X_r3 (1).pkl'
# X_r4_path=r'/content/X_r4 (1).pkl'
# Y_r_path=r'/content/Y_r (1).pkl'
# scaler_path=r'/content/scaler (1).pkl'

# try:
#   with open(X_r1_path, 'rb') as f:
#       X_r1 = pickle.load(f)

#   with open(X_r2_path, 'rb') as f:
#       X_r2 = pickle.load(f)

#   with open(X_r3_path, 'rb') as f:
#       X_r3 = pickle.load(f)

#   with open(X_r4_path, 'rb') as f:
#       X_r4 = pickle.load(f)

#   with open(Y_r_path, 'rb') as f:
#       Y_r = pickle.load(f)

#   with open(scaler_path, 'rb') as f:
#       scaler = joblib.load(f)

#   print("X_r1, X_r2, X_r3, X_r4 and Y_r loaded successfully!")
# except FileNotFoundError:
#   print("Saved data not found. Please ensure you saved X_r1, X_r2, X_r3, X_r4 and Y_r in the working directory.")
# df1=pd.DataFrame(np.concatenate((X_r1,X_r2,X_r3,X_r4),axis=0))
# y = Y_r
# y = np.array(y)
# X = df1

# %%
df1.shape
# Out:
# (48648, 4536)

# %% [markdown]
# ## Data Preparation for modelling
#
# * <span style="color:gray;"> Split data for training and testing</span>
# * <span style="color:gray;"> Normalize the data and save into offline file</span>
# * <span style="color:gray;"> Encode emotion labels into numbers</span>

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
# X_train.columns=X_train.columns.astype(str)
# X_test.columns=X_test.columns.astype(str)


#Normalize the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scalled = scaler.transform(X_train)
X_test_scalled = scaler.transform(X_test)
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
#Label Encoding
import keras.utils
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()

#Encode emotion labels into numbers
y_train_lb = keras.utils.to_categorical(lb.fit_transform(y_train))
y_test_lb = keras.utils.to_categorical(lb.fit_transform(y_test))

# Check out the data
print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train_lb.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test_lb.shape}')
# Out:
# X_train shape: (38918, 4536)
# y_train shape: (38918, 7)
# X_test shape: (9730, 4536)
# y_test shape: (9730, 7)

# %% [markdown]
# ## Modelling
#
# <span style="color:gray;">CNN Model</span>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dropout, Dense, MaxPool1D, AvgPool1D
import tensorflow as tf
# detect and init the TPU
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    raise BaseException('ERROR: Not connected to a TPU runtime; please check your runtime type.')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)



# instantiating the model in the strategy scope creates the model on the TPU
with tpu_strategy.scope():
# Build sequential CNN
  CNN_model = tf.keras.models.Sequential([
                        Conv1D(512, 5, padding='same', input_shape=(4536, 1), activation='relu'),
                        BatchNormalization(),
                        AvgPool1D(padding='same',strides=3,pool_size=5),
                        Dropout(0.6),

                        Conv1D(64, 5, padding='same', activation='relu'),
                        BatchNormalization(),

                        Conv1D(32, 5, padding='same', activation='relu'),
                        BatchNormalization(),
                        Dropout(0.3),

                        Flatten(),
                        Dense(256,activation='relu'),
                        Dropout(0.37),
                        Dense(128,activation='relu'),
                        Dense(7,activation='softmax')

])
  CNN_model.compile(loss = 'categorical_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
# Out:
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.

# %%
X_train.shape
# Out:
# (38918, 4536)

# %%
x_traincnn = np.expand_dims(X_train_scalled, axis=2)
x_testcnn = np.expand_dims(X_test_scalled, axis=2)

#Check shapes of dataframes
print(x_traincnn.shape)
print(x_testcnn.shape)
# Out:
# (38918, 4536, 1)
# (9730, 4536, 1)

# %%
CNN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4536, 512)         3072
#
#  batch_normalization (Batch  (None, 4536, 512)         2048
#  Normalization)
#
#  average_pooling1d (Average  (None, 1512, 512)         0
#  Pooling1D)
#
#  dropout (Dropout)           (None, 1512, 512)         0
#
#  conv1d_1 (Conv1D)           (None, 1512, 64)          163904
#
#  batch_normalization_1 (Bat  (None, 1512, 64)          256
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 1512, 32)          10272
#
#  batch_normalization_2 (Bat  (None, 1512, 32)          128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1512, 32)          0
#
#  flatten (Flatten)           (None, 48384)             0
#
#  dense (Dense)               (None, 256)               12386560
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 12600039 (48.07 MB)
# Trainable params: 12598823 (48.06 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=5, min_lr=0.001)
check_loss = ModelCheckpoint(filepath='saved_models/weights.best.basic_cnn-1.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
check_acc = ModelCheckpoint(filepath='saved_models/weights.best.basic_cnn-2.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
#early_stopping = EarlyStopping(monitor='val_accuracy', mode='max', patience=5)

#Model fit
cnn_results = CNN_model.fit(x_traincnn, y_train_lb,
              batch_size = 64,
              epochs = 100,
              verbose = 1,
              validation_data = (x_testcnn, y_test_lb),
              callbacks=[check_loss,check_acc,reduce_lr])
# Out:
# Epoch 1/100
# 609/609 [==============================] - ETA: 0s - loss: 1.5135 - accuracy: 0.4219
# Epoch 1: val_loss improved from inf to 1.21013, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.50504, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 37s 45ms/step - loss: 1.5135 - accuracy: 0.4219 - val_loss: 1.2101 - val_accuracy: 0.5050 - lr: 0.0010
# Epoch 2/100
# 608/609 [============================>.] - ETA: 0s - loss: 1.2321 - accuracy: 0.5109
# Epoch 2: val_loss improved from 1.21013 to 1.12076, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 2: val_accuracy improved from 0.50504 to 0.55529, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 1.2320 - accuracy: 0.5109 - val_loss: 1.1208 - val_accuracy: 0.5553 - lr: 0.0010
# Epoch 3/100
# 608/609 [============================>.] - ETA: 0s - loss: 1.0907 - accuracy: 0.5703
# Epoch 3: val_loss improved from 1.12076 to 1.06264, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 3: val_accuracy improved from 0.55529 to 0.60483, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 1.0908 - accuracy: 0.5703 - val_loss: 1.0626 - val_accuracy: 0.6048 - lr: 0.0010
# Epoch 4/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.9608 - accuracy: 0.6272
# Epoch 4: val_loss improved from 1.06264 to 0.92193, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 4: val_accuracy improved from 0.60483 to 0.65509, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.9608 - accuracy: 0.6271 - val_loss: 0.9219 - val_accuracy: 0.6551 - lr: 0.0010
# Epoch 5/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.8162 - accuracy: 0.6857
# Epoch 5: val_loss improved from 0.92193 to 0.89637, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 5: val_accuracy improved from 0.65509 to 0.66989, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.8160 - accuracy: 0.6857 - val_loss: 0.8964 - val_accuracy: 0.6699 - lr: 0.0010
# Epoch 6/100
# 609/609 [==============================] - ETA: 0s - loss: 0.6941 - accuracy: 0.7370
# Epoch 6: val_loss improved from 0.89637 to 0.75230, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 6: val_accuracy improved from 0.66989 to 0.72559, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.6941 - accuracy: 0.7370 - val_loss: 0.7523 - val_accuracy: 0.7256 - lr: 0.0010
# Epoch 7/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.5727 - accuracy: 0.7866
# Epoch 7: val_loss improved from 0.75230 to 0.68647, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 7: val_accuracy improved from 0.72559 to 0.75797, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.5727 - accuracy: 0.7866 - val_loss: 0.6865 - val_accuracy: 0.7580 - lr: 0.0010
# Epoch 8/100
# 609/609 [==============================] - ETA: 0s - loss: 0.4948 - accuracy: 0.8187
# Epoch 8: val_loss improved from 0.68647 to 0.64481, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 8: val_accuracy improved from 0.75797 to 0.77646, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.4948 - accuracy: 0.8187 - val_loss: 0.6448 - val_accuracy: 0.7765 - lr: 0.0010
# Epoch 9/100
# 609/609 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.8492
# Epoch 9: val_loss improved from 0.64481 to 0.62249, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 9: val_accuracy improved from 0.77646 to 0.78345, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 27ms/step - loss: 0.4180 - accuracy: 0.8492 - val_loss: 0.6225 - val_accuracy: 0.7835 - lr: 0.0010
# Epoch 10/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.3798 - accuracy: 0.8616
# Epoch 10: val_loss improved from 0.62249 to 0.57223, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 10: val_accuracy improved from 0.78345 to 0.80514, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.3798 - accuracy: 0.8615 - val_loss: 0.5722 - val_accuracy: 0.8051 - lr: 0.0010
# Epoch 11/100
# 609/609 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8792
# Epoch 11: val_loss improved from 0.57223 to 0.53433, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 11: val_accuracy improved from 0.80514 to 0.82425, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.3368 - accuracy: 0.8792 - val_loss: 0.5343 - val_accuracy: 0.8243 - lr: 0.0010
# Epoch 12/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.3030 - accuracy: 0.8918
# Epoch 12: val_loss improved from 0.53433 to 0.52858, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 12: val_accuracy improved from 0.82425 to 0.82950, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.3030 - accuracy: 0.8918 - val_loss: 0.5286 - val_accuracy: 0.8295 - lr: 0.0010
# Epoch 13/100
# 609/609 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9020
# Epoch 13: val_loss improved from 0.52858 to 0.49276, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 13: val_accuracy improved from 0.82950 to 0.84152, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.2693 - accuracy: 0.9020 - val_loss: 0.4928 - val_accuracy: 0.8415 - lr: 0.0010
# Epoch 14/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.2531 - accuracy: 0.9097
# Epoch 14: val_loss did not improve from 0.49276
#
# Epoch 14: val_accuracy improved from 0.84152 to 0.84573, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.2530 - accuracy: 0.9097 - val_loss: 0.4953 - val_accuracy: 0.8457 - lr: 0.0010
# Epoch 15/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.2328 - accuracy: 0.9190
# Epoch 15: val_loss improved from 0.49276 to 0.48966, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 15: val_accuracy improved from 0.84573 to 0.84697, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 29ms/step - loss: 0.2330 - accuracy: 0.9189 - val_loss: 0.4897 - val_accuracy: 0.8470 - lr: 0.0010
# Epoch 16/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.2128 - accuracy: 0.9251
# Epoch 16: val_loss improved from 0.48966 to 0.46511, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 16: val_accuracy improved from 0.84697 to 0.85231, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.2128 - accuracy: 0.9251 - val_loss: 0.4651 - val_accuracy: 0.8523 - lr: 0.0010
# Epoch 17/100
# 609/609 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.9291
# Epoch 17: val_loss improved from 0.46511 to 0.45008, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 17: val_accuracy did not improve from 0.85231
# 609/609 [==============================] - 16s 26ms/step - loss: 0.2030 - accuracy: 0.9291 - val_loss: 0.4501 - val_accuracy: 0.8521 - lr: 0.0010
# Epoch 18/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.1937 - accuracy: 0.9317
# Epoch 18: val_loss improved from 0.45008 to 0.44478, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 18: val_accuracy improved from 0.85231 to 0.86413, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.1937 - accuracy: 0.9317 - val_loss: 0.4448 - val_accuracy: 0.8641 - lr: 0.0010
# Epoch 19/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.1774 - accuracy: 0.9361
# Epoch 19: val_loss did not improve from 0.44478
#
# Epoch 19: val_accuracy did not improve from 0.86413
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1775 - accuracy: 0.9360 - val_loss: 0.4512 - val_accuracy: 0.8576 - lr: 0.0010
# Epoch 20/100
# 609/609 [==============================] - ETA: 0s - loss: 0.1702 - accuracy: 0.9397
# Epoch 20: val_loss did not improve from 0.44478
#
# Epoch 20: val_accuracy did not improve from 0.86413
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1702 - accuracy: 0.9397 - val_loss: 0.4720 - val_accuracy: 0.8565 - lr: 0.0010
# Epoch 21/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.1608 - accuracy: 0.9436
# Epoch 21: val_loss did not improve from 0.44478
#
# Epoch 21: val_accuracy improved from 0.86413 to 0.86598, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 27ms/step - loss: 0.1608 - accuracy: 0.9436 - val_loss: 0.4537 - val_accuracy: 0.8660 - lr: 0.0010
# Epoch 22/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.1570 - accuracy: 0.9453
# Epoch 22: val_loss improved from 0.44478 to 0.43589, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 22: val_accuracy improved from 0.86598 to 0.86814, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.1570 - accuracy: 0.9453 - val_loss: 0.4359 - val_accuracy: 0.8681 - lr: 0.0010
# Epoch 23/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9484
# Epoch 23: val_loss improved from 0.43589 to 0.43046, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 23: val_accuracy improved from 0.86814 to 0.87215, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.1487 - accuracy: 0.9484 - val_loss: 0.4305 - val_accuracy: 0.8721 - lr: 0.0010
# Epoch 24/100
# 609/609 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9525
# Epoch 24: val_loss improved from 0.43046 to 0.41933, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 24: val_accuracy did not improve from 0.87215
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1379 - accuracy: 0.9525 - val_loss: 0.4193 - val_accuracy: 0.8695 - lr: 0.0010
# Epoch 25/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.1334 - accuracy: 0.9552
# Epoch 25: val_loss improved from 0.41933 to 0.41756, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 25: val_accuracy did not improve from 0.87215
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1334 - accuracy: 0.9552 - val_loss: 0.4176 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 26/100
# 609/609 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9565
# Epoch 26: val_loss did not improve from 0.41756
#
# Epoch 26: val_accuracy improved from 0.87215 to 0.87400, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1294 - accuracy: 0.9565 - val_loss: 0.4232 - val_accuracy: 0.8740 - lr: 0.0010
# Epoch 27/100
# 609/609 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9552
# Epoch 27: val_loss did not improve from 0.41756
#
# Epoch 27: val_accuracy improved from 0.87400 to 0.87533, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1290 - accuracy: 0.9552 - val_loss: 0.4250 - val_accuracy: 0.8753 - lr: 0.0010
# Epoch 28/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.1213 - accuracy: 0.9590
# Epoch 28: val_loss improved from 0.41756 to 0.40771, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 28: val_accuracy did not improve from 0.87533
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1212 - accuracy: 0.9590 - val_loss: 0.4077 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 29/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.1152 - accuracy: 0.9604
# Epoch 29: val_loss did not improve from 0.40771
#
# Epoch 29: val_accuracy improved from 0.87533 to 0.87770, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1152 - accuracy: 0.9604 - val_loss: 0.4150 - val_accuracy: 0.8777 - lr: 0.0010
# Epoch 30/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.1103 - accuracy: 0.9618
# Epoch 30: val_loss did not improve from 0.40771
#
# Epoch 30: val_accuracy improved from 0.87770 to 0.88016, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 27ms/step - loss: 0.1103 - accuracy: 0.9618 - val_loss: 0.4161 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 31/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.1077 - accuracy: 0.9632
# Epoch 31: val_loss did not improve from 0.40771
#
# Epoch 31: val_accuracy did not improve from 0.88016
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1077 - accuracy: 0.9632 - val_loss: 0.4307 - val_accuracy: 0.8755 - lr: 0.0010
# Epoch 32/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.1034 - accuracy: 0.9635
# Epoch 32: val_loss did not improve from 0.40771
#
# Epoch 32: val_accuracy did not improve from 0.88016
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1035 - accuracy: 0.9634 - val_loss: 0.4246 - val_accuracy: 0.8760 - lr: 0.0010
# Epoch 33/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.9656
# Epoch 33: val_loss did not improve from 0.40771
#
# Epoch 33: val_accuracy improved from 0.88016 to 0.88181, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1001 - accuracy: 0.9655 - val_loss: 0.4205 - val_accuracy: 0.8818 - lr: 0.0010
# Epoch 34/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0985 - accuracy: 0.9669
# Epoch 34: val_loss did not improve from 0.40771
#
# Epoch 34: val_accuracy did not improve from 0.88181
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0985 - accuracy: 0.9669 - val_loss: 0.4124 - val_accuracy: 0.8786 - lr: 0.0010
# Epoch 35/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9681
# Epoch 35: val_loss did not improve from 0.40771
#
# Epoch 35: val_accuracy improved from 0.88181 to 0.88232, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0943 - accuracy: 0.9681 - val_loss: 0.4246 - val_accuracy: 0.8823 - lr: 0.0010
# Epoch 36/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0931 - accuracy: 0.9684
# Epoch 36: val_loss did not improve from 0.40771
#
# Epoch 36: val_accuracy improved from 0.88232 to 0.88499, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 27ms/step - loss: 0.0930 - accuracy: 0.9683 - val_loss: 0.4133 - val_accuracy: 0.8850 - lr: 0.0010
# Epoch 37/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0885 - accuracy: 0.9688
# Epoch 37: val_loss did not improve from 0.40771
#
# Epoch 37: val_accuracy did not improve from 0.88499
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0886 - accuracy: 0.9688 - val_loss: 0.4144 - val_accuracy: 0.8845 - lr: 0.0010
# Epoch 38/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0854 - accuracy: 0.9719
# Epoch 38: val_loss did not improve from 0.40771
#
# Epoch 38: val_accuracy improved from 0.88499 to 0.88510, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 27ms/step - loss: 0.0856 - accuracy: 0.9719 - val_loss: 0.4132 - val_accuracy: 0.8851 - lr: 0.0010
# Epoch 39/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0876 - accuracy: 0.9693
# Epoch 39: val_loss did not improve from 0.40771
#
# Epoch 39: val_accuracy did not improve from 0.88510
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0876 - accuracy: 0.9693 - val_loss: 0.4579 - val_accuracy: 0.8850 - lr: 0.0010
# Epoch 40/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9707
# Epoch 40: val_loss did not improve from 0.40771
#
# Epoch 40: val_accuracy did not improve from 0.88510
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0872 - accuracy: 0.9707 - val_loss: 0.4162 - val_accuracy: 0.8820 - lr: 0.0010
# Epoch 41/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9730
# Epoch 41: val_loss improved from 0.40771 to 0.40207, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 41: val_accuracy improved from 0.88510 to 0.88643, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.0791 - accuracy: 0.9730 - val_loss: 0.4021 - val_accuracy: 0.8864 - lr: 0.0010
# Epoch 42/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0781 - accuracy: 0.9733
# Epoch 42: val_loss did not improve from 0.40207
#
# Epoch 42: val_accuracy did not improve from 0.88643
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0781 - accuracy: 0.9733 - val_loss: 0.4184 - val_accuracy: 0.8823 - lr: 0.0010
# Epoch 43/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0772 - accuracy: 0.9748
# Epoch 43: val_loss did not improve from 0.40207
#
# Epoch 43: val_accuracy did not improve from 0.88643
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0772 - accuracy: 0.9748 - val_loss: 0.4357 - val_accuracy: 0.8825 - lr: 0.0010
# Epoch 44/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0755 - accuracy: 0.9746
# Epoch 44: val_loss did not improve from 0.40207
#
# Epoch 44: val_accuracy did not improve from 0.88643
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0755 - accuracy: 0.9746 - val_loss: 0.4132 - val_accuracy: 0.8768 - lr: 0.0010
# Epoch 45/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0702 - accuracy: 0.9759
# Epoch 45: val_loss did not improve from 0.40207
#
# Epoch 45: val_accuracy improved from 0.88643 to 0.88654, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0702 - accuracy: 0.9759 - val_loss: 0.4605 - val_accuracy: 0.8865 - lr: 0.0010
# Epoch 46/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0717 - accuracy: 0.9755
# Epoch 46: val_loss did not improve from 0.40207
#
# Epoch 46: val_accuracy did not improve from 0.88654
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0716 - accuracy: 0.9755 - val_loss: 0.4127 - val_accuracy: 0.8849 - lr: 0.0010
# Epoch 47/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0690 - accuracy: 0.9773
# Epoch 47: val_loss did not improve from 0.40207
#
# Epoch 47: val_accuracy did not improve from 0.88654
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0690 - accuracy: 0.9773 - val_loss: 0.5168 - val_accuracy: 0.8847 - lr: 0.0010
# Epoch 48/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0684 - accuracy: 0.9767
# Epoch 48: val_loss did not improve from 0.40207
#
# Epoch 48: val_accuracy did not improve from 0.88654
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0686 - accuracy: 0.9767 - val_loss: 0.4832 - val_accuracy: 0.8826 - lr: 0.0010
# Epoch 49/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9751
# Epoch 49: val_loss did not improve from 0.40207
#
# Epoch 49: val_accuracy did not improve from 0.88654
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0713 - accuracy: 0.9751 - val_loss: 0.4567 - val_accuracy: 0.8857 - lr: 0.0010
# Epoch 50/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0666 - accuracy: 0.9781
# Epoch 50: val_loss did not improve from 0.40207
#
# Epoch 50: val_accuracy did not improve from 0.88654
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0666 - accuracy: 0.9781 - val_loss: 0.4209 - val_accuracy: 0.8834 - lr: 0.0010
# Epoch 51/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0641 - accuracy: 0.9787
# Epoch 51: val_loss did not improve from 0.40207
#
# Epoch 51: val_accuracy improved from 0.88654 to 0.88726, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0641 - accuracy: 0.9787 - val_loss: 0.4507 - val_accuracy: 0.8873 - lr: 0.0010
# Epoch 52/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0607 - accuracy: 0.9798
# Epoch 52: val_loss did not improve from 0.40207
#
# Epoch 52: val_accuracy improved from 0.88726 to 0.88972, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 17s 28ms/step - loss: 0.0607 - accuracy: 0.9798 - val_loss: 0.5118 - val_accuracy: 0.8897 - lr: 0.0010
# Epoch 53/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9812
# Epoch 53: val_loss did not improve from 0.40207
#
# Epoch 53: val_accuracy did not improve from 0.88972
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0588 - accuracy: 0.9812 - val_loss: 0.4213 - val_accuracy: 0.8742 - lr: 0.0010
# Epoch 54/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0600 - accuracy: 0.9798
# Epoch 54: val_loss did not improve from 0.40207
#
# Epoch 54: val_accuracy did not improve from 0.88972
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0602 - accuracy: 0.9797 - val_loss: 0.4117 - val_accuracy: 0.8850 - lr: 0.0010
# Epoch 55/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.9791
# Epoch 55: val_loss did not improve from 0.40207
#
# Epoch 55: val_accuracy did not improve from 0.88972
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0621 - accuracy: 0.9791 - val_loss: 0.4286 - val_accuracy: 0.8867 - lr: 0.0010
# Epoch 56/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9800
# Epoch 56: val_loss did not improve from 0.40207
#
# Epoch 56: val_accuracy improved from 0.88972 to 0.89147, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 27ms/step - loss: 0.0603 - accuracy: 0.9800 - val_loss: 0.4419 - val_accuracy: 0.8915 - lr: 0.0010
# Epoch 57/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0616 - accuracy: 0.9801
# Epoch 57: val_loss did not improve from 0.40207
#
# Epoch 57: val_accuracy did not improve from 0.89147
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0616 - accuracy: 0.9801 - val_loss: 0.4125 - val_accuracy: 0.8850 - lr: 0.0010
# Epoch 58/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0635 - accuracy: 0.9793
# Epoch 58: val_loss did not improve from 0.40207
#
# Epoch 58: val_accuracy did not improve from 0.89147
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0635 - accuracy: 0.9793 - val_loss: 0.4765 - val_accuracy: 0.8899 - lr: 0.0010
# Epoch 59/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9805
# Epoch 59: val_loss did not improve from 0.40207
#
# Epoch 59: val_accuracy did not improve from 0.89147
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0585 - accuracy: 0.9805 - val_loss: 0.4209 - val_accuracy: 0.8910 - lr: 0.0010
# Epoch 60/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0533 - accuracy: 0.9814
# Epoch 60: val_loss did not improve from 0.40207
#
# Epoch 60: val_accuracy improved from 0.89147 to 0.89168, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0535 - accuracy: 0.9814 - val_loss: 0.4242 - val_accuracy: 0.8917 - lr: 0.0010
# Epoch 61/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0564 - accuracy: 0.9815
# Epoch 61: val_loss did not improve from 0.40207
#
# Epoch 61: val_accuracy did not improve from 0.89168
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0564 - accuracy: 0.9815 - val_loss: 0.4322 - val_accuracy: 0.8811 - lr: 0.0010
# Epoch 62/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9809
# Epoch 62: val_loss did not improve from 0.40207
#
# Epoch 62: val_accuracy improved from 0.89168 to 0.89291, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0559 - accuracy: 0.9809 - val_loss: 0.4197 - val_accuracy: 0.8929 - lr: 0.0010
# Epoch 63/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9817
# Epoch 63: val_loss did not improve from 0.40207
#
# Epoch 63: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0543 - accuracy: 0.9817 - val_loss: 0.4177 - val_accuracy: 0.8818 - lr: 0.0010
# Epoch 64/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0555 - accuracy: 0.9817
# Epoch 64: val_loss did not improve from 0.40207
#
# Epoch 64: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0555 - accuracy: 0.9817 - val_loss: 0.4083 - val_accuracy: 0.8858 - lr: 0.0010
# Epoch 65/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9818
# Epoch 65: val_loss did not improve from 0.40207
#
# Epoch 65: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0539 - accuracy: 0.9818 - val_loss: 0.4336 - val_accuracy: 0.8922 - lr: 0.0010
# Epoch 66/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9825
# Epoch 66: val_loss improved from 0.40207 to 0.40062, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 66: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0526 - accuracy: 0.9825 - val_loss: 0.4006 - val_accuracy: 0.8839 - lr: 0.0010
# Epoch 67/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9836
# Epoch 67: val_loss did not improve from 0.40062
#
# Epoch 67: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0479 - accuracy: 0.9836 - val_loss: 0.4333 - val_accuracy: 0.8877 - lr: 0.0010
# Epoch 68/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9826
# Epoch 68: val_loss did not improve from 0.40062
#
# Epoch 68: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0522 - accuracy: 0.9825 - val_loss: 0.4300 - val_accuracy: 0.8880 - lr: 0.0010
# Epoch 69/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9849
# Epoch 69: val_loss did not improve from 0.40062
#
# Epoch 69: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0457 - accuracy: 0.9849 - val_loss: 0.5093 - val_accuracy: 0.8889 - lr: 0.0010
# Epoch 70/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9846
# Epoch 70: val_loss did not improve from 0.40062
#
# Epoch 70: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0484 - accuracy: 0.9846 - val_loss: 0.4243 - val_accuracy: 0.8915 - lr: 0.0010
# Epoch 71/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9828
# Epoch 71: val_loss did not improve from 0.40062
#
# Epoch 71: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0519 - accuracy: 0.9828 - val_loss: 0.4052 - val_accuracy: 0.8868 - lr: 0.0010
# Epoch 72/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9852
# Epoch 72: val_loss did not improve from 0.40062
#
# Epoch 72: val_accuracy did not improve from 0.89291
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0424 - accuracy: 0.9852 - val_loss: 0.4034 - val_accuracy: 0.8811 - lr: 0.0010
# Epoch 73/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0483 - accuracy: 0.9841
# Epoch 73: val_loss did not improve from 0.40062
#
# Epoch 73: val_accuracy improved from 0.89291 to 0.89435, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 27ms/step - loss: 0.0483 - accuracy: 0.9841 - val_loss: 0.4352 - val_accuracy: 0.8943 - lr: 0.0010
# Epoch 74/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0502 - accuracy: 0.9830
# Epoch 74: val_loss did not improve from 0.40062
#
# Epoch 74: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0502 - accuracy: 0.9830 - val_loss: 0.4336 - val_accuracy: 0.8773 - lr: 0.0010
# Epoch 75/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0472 - accuracy: 0.9842
# Epoch 75: val_loss did not improve from 0.40062
#
# Epoch 75: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0471 - accuracy: 0.9842 - val_loss: 0.4190 - val_accuracy: 0.8751 - lr: 0.0010
# Epoch 76/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9849
# Epoch 76: val_loss did not improve from 0.40062
#
# Epoch 76: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0455 - accuracy: 0.9849 - val_loss: 0.4659 - val_accuracy: 0.8910 - lr: 0.0010
# Epoch 77/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9846
# Epoch 77: val_loss did not improve from 0.40062
#
# Epoch 77: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0461 - accuracy: 0.9846 - val_loss: 0.4046 - val_accuracy: 0.8735 - lr: 0.0010
# Epoch 78/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0473 - accuracy: 0.9846
# Epoch 78: val_loss did not improve from 0.40062
#
# Epoch 78: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0473 - accuracy: 0.9846 - val_loss: 0.4366 - val_accuracy: 0.8914 - lr: 0.0010
# Epoch 79/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0434 - accuracy: 0.9856
# Epoch 79: val_loss did not improve from 0.40062
#
# Epoch 79: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0435 - accuracy: 0.9856 - val_loss: 0.4168 - val_accuracy: 0.8857 - lr: 0.0010
# Epoch 80/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9849
# Epoch 80: val_loss did not improve from 0.40062
#
# Epoch 80: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0453 - accuracy: 0.9849 - val_loss: 0.4455 - val_accuracy: 0.8926 - lr: 0.0010
# Epoch 81/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9872
# Epoch 81: val_loss did not improve from 0.40062
#
# Epoch 81: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 0.4434 - val_accuracy: 0.8905 - lr: 0.0010
# Epoch 82/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9850
# Epoch 82: val_loss did not improve from 0.40062
#
# Epoch 82: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0443 - accuracy: 0.9850 - val_loss: 0.4201 - val_accuracy: 0.8856 - lr: 0.0010
# Epoch 83/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9861
# Epoch 83: val_loss did not improve from 0.40062
#
# Epoch 83: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0422 - accuracy: 0.9861 - val_loss: 0.5192 - val_accuracy: 0.8911 - lr: 0.0010
# Epoch 84/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9855
# Epoch 84: val_loss did not improve from 0.40062
#
# Epoch 84: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0447 - accuracy: 0.9855 - val_loss: 0.4326 - val_accuracy: 0.8919 - lr: 0.0010
# Epoch 85/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9861
# Epoch 85: val_loss did not improve from 0.40062
#
# Epoch 85: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0428 - accuracy: 0.9861 - val_loss: 0.5919 - val_accuracy: 0.8838 - lr: 0.0010
# Epoch 86/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9863
# Epoch 86: val_loss did not improve from 0.40062
#
# Epoch 86: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.4012 - val_accuracy: 0.8897 - lr: 0.0010
# Epoch 87/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9863
# Epoch 87: val_loss did not improve from 0.40062
#
# Epoch 87: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0423 - accuracy: 0.9863 - val_loss: 0.4993 - val_accuracy: 0.8917 - lr: 0.0010
# Epoch 88/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9863
# Epoch 88: val_loss did not improve from 0.40062
#
# Epoch 88: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0415 - accuracy: 0.9863 - val_loss: 0.4181 - val_accuracy: 0.8911 - lr: 0.0010
# Epoch 89/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0402 - accuracy: 0.9873
# Epoch 89: val_loss improved from 0.40062 to 0.39487, saving model to saved_models/weights.best.basic_cnn-1.keras
#
# Epoch 89: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0401 - accuracy: 0.9873 - val_loss: 0.3949 - val_accuracy: 0.8816 - lr: 0.0010
# Epoch 90/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9865
# Epoch 90: val_loss did not improve from 0.39487
#
# Epoch 90: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0418 - accuracy: 0.9865 - val_loss: 0.4268 - val_accuracy: 0.8923 - lr: 0.0010
# Epoch 91/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 0.9868
# Epoch 91: val_loss did not improve from 0.39487
#
# Epoch 91: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0391 - accuracy: 0.9868 - val_loss: 0.4094 - val_accuracy: 0.8892 - lr: 0.0010
# Epoch 92/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9874
# Epoch 92: val_loss did not improve from 0.39487
#
# Epoch 92: val_accuracy did not improve from 0.89435
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0387 - accuracy: 0.9874 - val_loss: 0.4041 - val_accuracy: 0.8904 - lr: 0.0010
# Epoch 93/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9873
# Epoch 93: val_loss did not improve from 0.39487
#
# Epoch 93: val_accuracy improved from 0.89435 to 0.89579, saving model to saved_models/weights.best.basic_cnn-2.keras
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.4635 - val_accuracy: 0.8958 - lr: 0.0010
# Epoch 94/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9880
# Epoch 94: val_loss did not improve from 0.39487
#
# Epoch 94: val_accuracy did not improve from 0.89579
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0363 - accuracy: 0.9880 - val_loss: 0.4725 - val_accuracy: 0.8912 - lr: 0.0010
# Epoch 95/100
# 608/609 [============================>.] - ETA: 0s - loss: 0.0396 - accuracy: 0.9871
# Epoch 95: val_loss did not improve from 0.39487
#
# Epoch 95: val_accuracy did not improve from 0.89579
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.4670 - val_accuracy: 0.8930 - lr: 0.0010
# Epoch 96/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0360 - accuracy: 0.9888
# Epoch 96: val_loss did not improve from 0.39487
#
# Epoch 96: val_accuracy did not improve from 0.89579
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0359 - accuracy: 0.9888 - val_loss: 0.4363 - val_accuracy: 0.8922 - lr: 0.0010
# Epoch 97/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9890
# Epoch 97: val_loss did not improve from 0.39487
#
# Epoch 97: val_accuracy did not improve from 0.89579
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0332 - accuracy: 0.9890 - val_loss: 0.5615 - val_accuracy: 0.8940 - lr: 0.0010
# Epoch 98/100
# 607/609 [============================>.] - ETA: 0s - loss: 0.0377 - accuracy: 0.9879
# Epoch 98: val_loss did not improve from 0.39487
#
# Epoch 98: val_accuracy did not improve from 0.89579
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0376 - accuracy: 0.9879 - val_loss: 0.4164 - val_accuracy: 0.8918 - lr: 0.0010
# Epoch 99/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9881
# Epoch 99: val_loss did not improve from 0.39487
#
# Epoch 99: val_accuracy did not improve from 0.89579
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 0.4284 - val_accuracy: 0.8930 - lr: 0.0010
# Epoch 100/100
# 609/609 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9879
# Epoch 100: val_loss did not improve from 0.39487
#
# Epoch 100: val_accuracy did not improve from 0.89579
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0381 - accuracy: 0.9879 - val_loss: 0.4335 - val_accuracy: 0.8905 - lr: 0.0010

# %%
from google.colab import files

# Specify the path to your output file
output_file_path_1 = '/content/saved_models/weights.best.basic_cnn-1.keras'
output_file_path_2 = '/content/saved_models/weights.best.basic_cnn-2.keras'
files.download(output_file_path_1)
files.download(output_file_path_2)

# %% [markdown]
# ## Accuracy

# %%
# Calculate pre-training accuracy
score = CNN_model.evaluate(x_testcnn, y_test_lb, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# 305/305 [==============================] - 5s 10ms/step - loss: 0.4334 - accuracy: 0.8906
# Pre-training accuracy: 89.0647%

# %%
# Evaluating the model on the training and testing set
score = CNN_model.evaluate(x_traincnn, y_train_lb, verbose=0)
print("Training Accuracy: ", score[1])

score = CNN_model.evaluate(x_testcnn, y_test_lb, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9999229311943054
# Testing Accuracy:  0.8906474709510803

# %%
plt.plot(cnn_results.history['accuracy'])
plt.plot(cnn_results.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(cnn_results.history['loss'])
plt.plot(cnn_results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
CNN_model.save('my_model.h5')
files.download('my_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
CNN_model.load_weights('my_model.h5')
CNN_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
val_loss, val_acc = CNN_model.evaluate(x_testcnn, y_test_lb)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_acc)
# Out:
# 305/305 [==============================] - 5s 10ms/step - loss: 0.4330 - accuracy: 0.8904
# Validation Loss: 0.43303585052490234
# Validation Accuracy: 0.8904419541358948

# %%
from sklearn.tree import DecisionTreeClassifier

#fitting the DT
DT_model_one = DecisionTreeClassifier()
DT_model_one.fit(X_train, y_train_lb)

#Getting the score
print(f"The classification accuracy is: {DT_model_one.score(X_train, y_train_lb)}")
print(f"The classification accuracy is: {DT_model_one.score(X_test, y_test_lb)}")

# %%
# import librosa
# import joblib
# import numpy as np
# from tensorflow.keras.models import load_model
# from sklearn.preprocessing import StandardScaler, LabelEncoder

# # Function to preprocess new audio file
# def preprocess_audio(file_path):
#     data, sample_rate = librosa.load(file_path, duration=2.5, offset=0.6)
#     features = extract_feature(data, sample_rate)
#     features_scaled = scaler.transform([features])
#     features_scaled = np.expand_dims(features_scaled, axis=2)
#     return features_scaled

# # Example file path to a new audio file
# new_audio_file_path = '/kaggle/input/cremad/AudioWAV/1001_IEO_FEA_HI.wav'
# new_audio_features = preprocess_audio(new_audio_file_path)

# # Predict the emotion
# predicted_emotion_probabilities = CNN_model.predict(new_audio_features)
# predicted_emotion = np.argmax(predicted_emotion_probabilities, axis=1)
# emotion_labels = ['neutral', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']
# predicted_emotion_label = emotion_labels[predicted_emotion[0]]

# print(f'Predicted Emotion: {predicted_emotion_label}')

# %%
raise Exception("Timeout!")
